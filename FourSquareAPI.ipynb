# %% [markdown]
# ## **Four Square APIs**
#
# This tutorial provides a brief description of how getting started with Foursquare API. You will also find a good tutorial here:
# https://www.kaggle.com/code/kristoft/tutorial-foursquare-api-search

# %% [markdown]
# **Getting Started**
#
# Foursquare API provides a range of tools for developers to incorporate the up-to-date location data to enhance their projects.
#
# To start using Foursquare, first, let’s create a new account at https://developer.foursquare.com/ . The default account is called Sandbox Account. Sandbox Account provides you a limited set of tools, for instance, you‘ll be able to make only 950 Regular Calls / Day, and get 1 Photo and 1 Tip per Venue. Not too much, but it should be enough for a “toy” dataset (sure, you may also upgrade your account for future projects). Foursquare provides a simple UI to manage your account and to check your daily stats (like how many calls did you make). Once the account is created, you will be assigned credentials: the Client ID and the Client Secret.
#
# Ok, all set up and we can jump into coding. First and foremost, let’s import some necessary libraries: pandas.io.json(to tranforming json file into a pandas dataframe library), folium (plotting library), geopy.geocoders (module to convert an address into latitude and longitude values), and requests (library to handle requests).

# %%
# !pip install geopy
from pandas import json_normalize
import folium
import pandas as pd
from geopy.geocoders import Nominatim
import requests
# Out:
# Requirement already satisfied: geopy in /Users/delmelle/miniforge3/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from geopy) (2.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Next, lets define our Foursquare credentials and version into python code:

# %%
CLIENT_ID = "AX1O0GXCKC2YOCKBYWQRXPXQFLZBAZE5PKHGOPA5QRMJQWKI" # your Foursquare ID
CLIENT_SECRET = "XH34Z0ZQXNJSOWAL5EP4000O0UBYMJVI1UEFJTPKO0SZF24G" # your Foursquare Secret
VERSION = "20180604"
LIMIT = 100

# %% [markdown]
# Now, let’s assume you just moved to a new place which called the VUB and you want to explore your neighbourhood. So, let’s define a query to search the top 100 venues that are within 2500 meters from the VUB

# %%
# Select first building (which in our case is Penn):
neighborhood_name = 'VUB'

neighborhood_latitude = 50.8222
neighborhood_longitude = 4.3969

# limit of number of venues returned by Foursquare API
LIMIT = 100
radius = 2500

# %% [markdown]
# And now we define the corresponding URL and send the GET Request to Foursquare API and examine the results.

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    neighborhood_latitude,
    neighborhood_longitude,
    radius,
    LIMIT)
results = requests.get(url).json()
print(results)
# Out:
# {'meta': {'code': 200, 'requestId': '67cf15e3f13a8b56c9c25bdd'}, 'response': {'queryRefinements': {'target': {'type': 'path', 'url': '/venue/explore', 'params': {'ll': '50.822200,4.396900', 'radius': '2500'}}, 'refinements': [{'query': 'Food'}, {'query': 'Nightlife'}, {'query': 'Coffee'}, {'query': 'Shops'}, {'query': 'Arts'}, {'query': 'Outdoors'}]}, 'suggestedFilters': {'header': 'Tap to show:', 'filters': [{'name': 'Open now', 'key': 'openNow'}]}, 'headerLocation': 'Brussels', 'headerFullLocation': 'Brussels', 'headerLocationGranularity': 'city', 'totalResults': 179, 'suggestedBounds': {'ne': {'lat': 50.84470002250003, 'lng': 4.432450073905012}, 'sw': {'lat': 50.79969997749998, 'lng': 4.361349926094987}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4be871c288ed2d7f15e1cb1d', 'name': "Luigi's Café", 'contact': {'phone': '+3226469296', 'formattedPhone': '+32 2 646 92 96'}, 'location': {'address': 'Generaal Jacqueslaan 253 Boulevard Général Jacques', 'lat': 50.82181470577221, 'lng': 4.388259204962322, 'labeledLatLngs': [{'label': 'display', 'lat': 50.82181470577221, 'lng': 4.388259204962322}], 'distance': 609, 'postalCode': '1050', 'cc': 'BE', 'city': 'Brussel', 'state': 'Brussel-Hoofdstad', 'country': 'België', 'formattedAddress': ['Generaal Jacqueslaan 253 Boulevard Général Jacques', '1050 Elsene', 'België']}, 'categories': [{'id': '4bf58dd8d48988d11b941735', 'name': 'Pub', 'pluralName': 'Pubs', 'shortName': 'Pub', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}, 'categoryCode': 13018, 'mapIcon': 'fsq-bar', 'primary': True}], 'verified': True, 'stats': {'tipCount': 9, 'usersCount': 1165, 'checkinsCount': 10738}, 'url': 'https://www.bruzz.be/luigis-cafe-2012-02-03', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '€'}, 'header': 'According to the Foursquare community, this place is an 8.6 out of 10.', 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 76, 'explanation': "We take into account visits and input from our community. You'll see a number on places based off of ratings and tips written by people like you.", 'ratingCategory': 'great', 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'hours': {'status': 'Open until 06:00', 'richStatus': {'entities': [], 'text': 'Open until 06:00'}, 'isOpen': True, 'isLocalHoliday': False}, 'photos': {'count': 0, 'groups': []}, 'venuePage': {'id': '43628500'}, 'createdAt': 1273524674, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'popularityByGeo': 0.9892474607571561}, 'photo': {'id': '5187bc01498e5317976f60e8', 'createdAt': 1367849985, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/51090407_dIaWKi2bYwtI2pdJzvmwIxS1oMXNx51Kou2k1v_wFPk.jpg', 'width': 960, 'height': 720, 'visibility': 'public'}, 'tips': [{'id': '4fcb5115e4b0e6dca7c4d538', 'createdAt': 1338724629, 'text': 'Ons stamcafé en de plaats waar menig feestje ons tot de vroege uurtjes bezig houdt!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4fcb5115e4b0e6dca7c4d538', 'likes': {'count': 5, 'groups': [], 'summary': '5 likes'}, 'logView': True, 'agreeCount': 4, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Letteren- & WijsbegeerteKring VUB', 'handle': 'lwk_vub', 'privateProfile': False, 'countryCode': 'BE', 'followingRelationship': 'none', 'type': 'chain'}}], 'referralId': 'e-0-4be871c288ed2d7f15e1cb1d-0'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4f87fe32e4b005979cdc0156', 'name': 'Kings of Comedy Club', 'contact': {'phone': '+3226499930', 'formattedPhone': '+32 2 649 99 30', 'twitter': 'kingscomedyclub', 'facebook': '340902952625683', 'facebookUsername': 'kingsofcomedyclub' ...

# %% [markdown]
# Next, get relevant part of JSON and transform it into a pandas dataframe:

# %%
# assign relevant part of JSON to venues
venues = results['response']['groups'][0]['items']

# tranform venues into a pandas dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                 tips  \
# 0  [{'id': '4fcb5115e4b0e6dca7c4d538', 'createdAt...
# 1  [{'id': '508d03f1e4b0645d6766ce57', 'createdAt...
# 2  [{'id': '4b8d0ae070c603bb796293b4', 'createdAt...
# 3  [{'id': '59e87d0ca4b51b0e62d4c5fe', 'createdAt...
# 4  [{'id': '4faa4ad2e4b0328fbea2d135', 'createdAt...
#
#                        referralId  reasons.count  \
# 0  e-0-4be871c288ed2d7f15e1cb1d-0              0
# 1  e-0-4f87fe32e4b005979cdc0156-1              0
# 2  e-0-4b649474f964a5204abf2ae3-2              0
# 3  e-0-524abf5a11d22ca199294388-3              0
# 4  e-0-4b94038ef964a520566134e3-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id               venue.name venue.contact.phone  \
# 0  4be871c288ed2d7f15e1cb1d             Luigi's Café         +3226469296
# 1  4f87fe32e4b005979cdc0156     Kings of Comedy Club         +3226499930
# 2  4b649474f964a5204abf2ae3               Le Gauguin         +3226463972
# 3  524abf5a11d22ca199294388  Les Tartes de Françoise         +3226726272
# 4  4b94038ef964a520566134e3             Villa Singha         +3226756734
#
#   venue.contact.formattedPhone  \
# 0              +32 2 646 92 96
# 1              +32 2 649 99 30
# 2              +32 2 646 39 72
# 3              +32 2 672 62 72
# 4              +32 2 675 67 34
#
#                               venue.location.address  venue.location.lat  ...  \
# 0  Generaal Jacqueslaan 253 Boulevard Général Jac...           50.821815  ...
# 1        Boondaalsesteenweg 489 Chaussée de Boondael           50.815248  ...
# 2        Boondaalsesteenweg 420 Chaussée de Boondael           50.817488  ...
# 3                    Square Jean-Baptiste De Greef 2           50.820510  ...
# 4      22 Rue des Trois Ponts / Driebruggenstraat 22           50.820634  ...
#
#    venue.storeId venue.menu.type  venue.menu.label venue.menu.anchor  \
# 0            NaN             NaN               NaN               NaN
# 1                            NaN               NaN               NaN
# 2            NaN             NaN               NaN               NaN
# 3            NaN             NaN               NaN               NaN
# 4            NaN            Menu              Menu         View Menu
#
#                        venue.menu.url                venue.menu.mobileUrl  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4  http://www.singha.be/html/menu.htm  http://www.singha.be/html/menu.htm
#
#                venue.menu.externalUrl venue.location.crossStreet  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4  http://www.singha.be/html/menu.htm                        NaN
#
#   venue.venueRatingBlacklisted venue.contact.instagram
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# Define information of interest and filter the dataframe

# %%
# filter columns
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']

    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =dataframe.loc[:, filtered_columns]# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues.head(10)
# Out:
#                       name       categories        lat       lng
# 0             Luigi's Café              Pub  50.821815  4.388259
# 1     Kings of Comedy Club      Comedy Club  50.815248  4.389900
# 2               Le Gauguin              Bar  50.817488  4.388301
# 3  Les Tartes de Françoise         Pie Shop  50.820510  4.408903
# 4             Villa Singha  Thai Restaurant  50.820634  4.407810
# 5                Fresh Med      Supermarket  50.832297  4.403824
# 6           Peter & Sabine          Butcher  50.826114  4.412382
# 7              Pizza Liloo         Pizzeria  50.832825  4.386597
# 8  Les Tartes de Françoise         Pie Shop  50.820312  4.376851
# 9                   Mexigo  Taco Restaurant  50.811424  4.389857

# %% [markdown]
# Finally, lets visualize the venues around Penn. For this purpose I use Folium library (Folium is completely free). Generating the map is straigtforward in Folium. We only create a Folium Map object and display it. So, I generate a map centred around the Penn campus. Bellow is the python code:

# %%
venues_map = folium.Map(location=[neighborhood_latitude, neighborhood_longitude], zoom_start=15)

folium.features.CircleMarker(
    [neighborhood_latitude, neighborhood_longitude],
    radius=10,
    color='red',
    popup='UPENN',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


# add all venues as blue circle markers
for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1ebc7ddbaf9d536237509e04f04c54b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1ebc7ddbaf9d536237509e04f04c54b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1ebc7ddbaf9d536237509e04f04c54b = L.map(
#                 &quot;map_b1ebc7ddbaf9d536237509e04f04c54b&quot;,
#                 {
#                     center: [50.8222, 4.3969],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e7f6633d3ef403712cf6c509d07593f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6e7f6633d3ef403712cf6c509d07593f.addTo(map_b1ebc7ddbaf9d536237509e04f04c54b);
#
#
#             var circle_marker_3c548a79e67d4bcb0350c863b04c8427 = L.circleMarker(
#                 [50.8222, 4.3969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1ebc7ddbaf9d536237509e04f04c54b);
#
#
#         var popup_80a346ea19c38dc0794c84eb7e8af869 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c96f9ab3ccaaa9f7d56c9f96067d117 = $(`&lt;div id=&quot;html_4c96f9ab3ccaaa9f7d56c9f96067d117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UPENN&lt;/div&gt;`)[0];
#                 popup_80a346ea19c38dc0794c84eb7e8af869.setContent(html_4c96f9ab3ccaaa9f7d56c9f96067d117);
#
#
#
#         circle_marker_3c548a79e67d4bcb0350c863b04c8427.bindPopup(popup_80a346ea19c38dc0794c84eb7e8af869)
#         ;
#
#
#
#
#             var circle_marker_33ca87a713eea52c9f72de452cb89611 = L.circleMarker(
#                 [50.82181470577221, 4.388259204962322],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1ebc7ddbaf9d536237509e04f04c54b);
#
#
#         var popup_3afd3af35faee7a8c3c6617790135bdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1616469ae71c35bdd7fb132d156eadf7 = $(`&lt;div id=&quot;html_1616469ae71c35bdd7fb132d156eadf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Luigi&#x27;s Café&lt;/div&gt;`)[0];
#                 popup_3afd3af35faee7a8c3c6617790135bdb.setContent(html_1616469ae71c35bdd7fb132d156eadf7);
#
#
#
#         circle_marker_33ca87a713eea52c9f72de452cb89611.bindPopup(popup_3afd3af35faee7a8c3c6617790135bdb)
#         ;
#
#
#
#
#             var circle_marker_8ae22431b9b283082c22cba3e348918c = L.circleMarker(
#                 [50.81524836316787, 4.389899568763106],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1ebc7ddbaf9d536237509e04f04c54b);
#
#
#         var popup_ab3bd8d407d4ab63b3f9f4f1690b1a22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe731b5ec9bc1c10450324ef7e04e237 = $(`&lt;div id=&quot;html_fe731b5ec9bc1c10450324ef7e04e237&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kings of Comedy Club&lt;/div&gt;`)[0];
#                 popup_ab3bd8d407d4ab63b3f9f4f1690b1a22.setContent(html_fe731b5ec9bc1c10450324ef7e04e237);
#
#
#
#         circle_marker_8ae22431b9b283082c22cba3e348918c.bindPopup(popup_ab3bd8d407d4ab63b3f9f4f1690b1a22)
#         ;
#
#
#
#
#             var circle_marker_265f98e41f75491a66dc649d1a83ba39 = L.circleMarker(
#                 [50.81748809292179, 4.3883012533190255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot
